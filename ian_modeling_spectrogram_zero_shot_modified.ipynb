# %%
# Import necessary packages

import numpy as np
import torch 
import torch.nn as nn 
import pandas as pd
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import os 
from sklearn.model_selection import train_test_split
import random
from sklearn.preprocessing import normalize
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
# Navigate to directory that stores all the files - will need to be changed for each person running this script
os.chdir('/home/ian/Documents/Penn_Fall_2020/CIS_519/CIS 519 Audio Classification Project Local Files')
os.getcwd()
# Out:
# '/home/ian/Documents/Penn_Fall_2020/CIS_519/CIS 519 Audio Classification Project Local Files'

# %%
# Reload features (takes a couple minutes)
# features = np.load('features_with_gender.npy',allow_pickle=True)
features = np.load('features/features_spectrogram.npy',allow_pickle=True)

# %%
# Changing array type of features (Necessary for it to work with pytorch)

features = [example for example in features]

# %%
# Load in labels 
labels = np.load('labels.npy', allow_pickle=True)

# %%
# Load in gender
gender=np.load('gender.npy',allow_pickle=True)

# %%
# Turn labels into numeric values, create dictionary to map back later 

labels_unique = np.unique(labels)
labels_dict = {}
for i in range (0, len(labels_unique)):
    labels_dict.update({i:labels_unique[i]})

labels_dict_reversed = {value:key for key, value in labels_dict.items()}

def label_to_num(x):
    return labels_dict_reversed[x]

labels_numeric = [label_to_num(country) for country in labels]

# %% [markdown]
# #### Split into train and test sets: ZERO-SHOT

# %%
features_male = []
labels_male = []
features_female = []
labels_female = []

for i in range(len(gender)):
    if gender[i] == 0:
        features_male.append(features[i])
        labels_male.append(labels[i])
    else:
        features_female.append(features[i])
        labels_female.append(labels[i])
        
features_male = np.array(features_male)
features_female = np.array(features_female)
labels_male = np.array(labels_male)
labels_female = np.array(labels_female)

# %%
# Get train and test datasets
x_train, x_valid, y_train, y_valid = train_test_split(features_male, labels_male, test_size=0.3, random_state=42)
_, x_test, _, y_test = train_test_split(features_female, labels_female, test_size=0.3, random_state=142)

# %%
# Balance training data 

for y in labels_unique:
    print(str(y) + ' , Occurences: ' + str(list(labels).count(y)))
    
x_train_balanced = []
x_valid_balanced = []
y_train_balanced = []
y_valid_balanced = []
x_test_balanced = []
y_test_balanced = []

remap={}
keep = [0,1,6,7,8,12,13,18,19]

for i in range(0, len(keep)):
    remap[keep[i]] = i
    
print(remap)

    
for i in range(0, len(y_train)):
    if y_train[i] in keep:
        y_train_balanced.append(remap[y_train[i]])
        x_train_balanced.append(x_train[i])
        
for i in range(0, len(y_valid)):
    if y_valid[i] in keep:
        y_valid_balanced.append(remap[y_valid[i]])
        x_valid_balanced.append(x_valid[i])
        
for i in range(0, len(y_test)):
    if y_test[i] in keep:
        y_test_balanced.append(remap[y_test[i]])
        x_test_balanced.append(x_test[i])
# Out:
# 0 , Occurences: 500
# 1 , Occurences: 500
# 2 , Occurences: 91
# 3 , Occurences: 188
# 4 , Occurences: 144
# 5 , Occurences: 141
# 6 , Occurences: 500
# 7 , Occurences: 500
# 8 , Occurences: 500
# 9 , Occurences: 274
# 10 , Occurences: 392
# 11 , Occurences: 159
# 12 , Occurences: 500
# 13 , Occurences: 500
# 14 , Occurences: 243
# 15 , Occurences: 118
# 16 , Occurences: 88
# 17 , Occurences: 292
# 18 , Occurences: 500
# 19 , Occurences: 500
# {0: 0, 1: 1, 6: 2, 7: 3, 8: 4, 12: 5, 13: 6, 18: 7, 19: 8}

# %%
# Initializing number of outputs for neural network

output_label_num = len(labels_unique)

# %%
output_label_num
# Out:
# 20

# %%
# Convolutional 

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1,out_channels=6,kernel_size=3,stride=1,padding=0)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(in_channels=6,out_channels=10,kernel_size=3,stride=1,padding=0)
        self.fc1 = nn.Linear(10*254*10*1, 300)
        self.fc2 = nn.Linear(300, 100)
        self.fc3 = nn.Linear(100, output_label_num)
        self.dropout = nn.Dropout(p=.3)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 1*x.size()[1]*x.size()[2]*x.size()[3])
#         x = self.dropout(x)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    
class BalancedNet(nn.Module):
    def __init__(self):
        super(BalancedNet, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1,out_channels=10,kernel_size=3,stride=1,padding=0)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(in_channels=10,out_channels=15,kernel_size=3,stride=1,padding=0)
        self.fc1 = nn.Linear(15*254*10*1, 300)
        self.fc2 = nn.Linear(300, 100)
        self.fc3 = nn.Linear(100, len(keep))
        self.dropout = nn.Dropout(p=.3)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
#         x = self.dropout(x)
        x = self.pool(F.relu(self.conv2(x)))
#         x = self.dropout(x)
        x = x.view(-1, 1*x.size()[1]*x.size()[2]*x.size()[3])
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def compute_loss_and_accuracy(network, data_loader):
    total_loss = 0
    num_correct = 0
    num_instances = 0

    cross_entropy_loss = torch.nn.CrossEntropyLoss()

    for X, y in data_loader:
        with torch.no_grad():
            y_pred = network(X)
            total_loss += cross_entropy_loss(y_pred,y).item() * X.size(0)

        for i in range(len(y_pred)):
            predicted = torch.argmax(y_pred[i])
            actual = y[i]

            if predicted == actual:
                num_correct += 1
                
        num_instances += X.size(0)
  
    accuracy = num_correct / num_instances
    average_loss = total_loss / num_instances

    return accuracy, average_loss

# %%
# Creating function to compute loss/accuracy

def test_model(net, test_dataloader):

    total_loss = 0
    total_classified_correct = 0
    total_attempted = 0
    pred_vs_actual = []

    criterion = nn.CrossEntropyLoss()

    for x, y in test_dataloader:
        output = net(x)
        _, predicted = torch.max(output, 1)
        loss = criterion(output, y)
        total_loss += loss.item()
        total_classified_correct += (predicted==y).sum().item()
        total_attempted += len(predicted)
        pred_vs_actual.append((predicted.item(), y.item()))
        
    print('Test Average Loss: ' + str(total_loss/total_attempted))
    print('Test Accuracy: ' + str(total_classified_correct/total_attempted))
    
    
    return total_attempted, pred_vs_actual

# %%
def check_preds(pred_vs_acc):
    pred_list = []
    acc_list = []
    total_list = []
    for pred, acc in pred_vs_acc:
        pred_list.append(pred)
        acc_list.append(acc)
        total_list.append(1)
        
    df = pd.DataFrame({'predicted':pred_list, 'actual':acc_list, 'total':total_list})
    df = df.groupby(['predicted', 'actual']).count().reset_index()
    
    def get_correct(row):
        if row.predicted==row.actual:
            return 1 
        else:
            return 0
        
    df['is_correct'] = df.apply(lambda x: get_correct(x), axis=1)
    df['predicted_country'] = df.predicted.apply(lambda x: labels_dict[x])
    df['actual_country'] = df.actual.apply(lambda x: labels_dict[x])
    
    return df

# %%
# Creating training function

def train_model(epochs, net, train_dataloader, valid_dataloader, optimizer, criterion):

    train_loss_per_epoch = []
    train_acc_per_epoch = []
    valid_acc_per_epoch = []

    for epoch in range (0, epochs):

        train_total_loss = 0
        train_total_correct = 0
        train_total_attempted = 0

        for x, y in train_dataloader:
            optimizer.zero_grad()
            output = net(x)
            _, predicted = torch.max(output, 1)
            loss = criterion(output, y)
            loss.backward()
            optimizer.step()
        
        train_acc, train_loss = compute_loss_and_accuracy(net, train_dataloader)
        valid_acc, valid_loss = compute_loss_and_accuracy(net, valid_dataloader)
        
        train_loss_per_epoch.append(train_loss)
        train_acc_per_epoch.append(train_acc)
        valid_acc_per_epoch.append(valid_acc)

    
        print('Epoch ' + str(epoch) + ':')
        print('Train Average Loss: ' + str(train_loss))
        print('Train Accuracy: ' + str(train_acc))
        print('Validation Average Loss: ' + str(valid_loss))
        print('Validation Accuracy: ' + str(valid_acc))
        print()


    return train_acc_per_epoch, valid_acc_per_epoch

# train_model(1, net, train_dataloader, optimizer, criterion)

# %%
# Create dataloader objects, move to GPU

batch = 32

# Train
x_train_tensor = torch.tensor(x_train, dtype=torch.float)
x_train_tensor = x_train_tensor.unsqueeze(dim=1)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)

x_train_tensor = x_train_tensor.cuda()
y_train_tensor = y_train_tensor.cuda()

train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
train_dataloader = DataLoader(train_dataset, batch_size=batch)

# Validation
x_valid_tensor = torch.tensor(x_valid, dtype=torch.float)
x_valid_tensor = x_valid_tensor.unsqueeze(dim=1)
y_valid_tensor = torch.tensor(y_valid, dtype=torch.long)

x_valid_tensor = x_valid_tensor.cuda()
y_valid_tensor = y_valid_tensor.cuda()

valid_dataset = TensorDataset(x_valid_tensor, y_valid_tensor)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch)

# Test
x_test_tensor = torch.tensor(x_test, dtype=torch.float)
x_test_tensor = x_test_tensor.unsqueeze(dim=1)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

x_test_tensor = x_test_tensor.cuda()
y_test_tensor = y_test_tensor.cuda()

test_dataset = TensorDataset(x_test_tensor, y_test_tensor)
test_dataloader = DataLoader(test_dataset, batch_size=1)

# %%
# Initializing model, parameters, move to GPU

net = Net()
net = net.cuda()

optimizer = optim.SGD(net.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# Train Model
epochs = 100
train_accs, valid_accs = train_model(epochs, net, train_dataloader, valid_dataloader, optimizer, criterion)

epoch_list = [i for i in range(1, epochs+1)]
plt.figure()
plt.plot(epoch_list, train_accs, label='Train Accuracy')
plt.plot(epoch_list, valid_accs, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 0:
# Train Average Loss: 2.744272902037693
# Train Accuracy: 0.1339350180505415
# Validation Average Loss: 2.758701544418078
# Validation Accuracy: 0.11531986531986532
#
# Epoch 1:
# Train Average Loss: 2.704861604091493
# Train Accuracy: 0.1552346570397112
# Validation Average Loss: 2.732969328209206
# Validation Accuracy: 0.12626262626262627
#
# Epoch 2:
# Train Average Loss: 2.664298924470206
# Train Accuracy: 0.16859205776173286
# Validation Average Loss: 2.710441009765522
# Validation Accuracy: 0.1414141414141414
#
# Epoch 3:
# Train Average Loss: 2.63176772293201
# Train Accuracy: 0.17653429602888088
# Validation Average Loss: 2.6974447632478142
# Validation Accuracy: 0.1447811447811448
#
# Epoch 4:
# Train Average Loss: 2.6022361211398017
# Train Accuracy: 0.18231046931407943
# Validation Average Loss: 2.6903905643758548
# Validation Accuracy: 0.15235690235690236
#
# Epoch 5:
# Train Average Loss: 2.5725408046254183
# Train Accuracy: 0.1884476534296029
# Validation Average Loss: 2.683893322543263
# Validation Accuracy: 0.15572390572390574
#
# Epoch 6:
# Train Average Loss: 2.5426641221511237
# Train Accuracy: 0.2003610108303249
# Validation Average Loss: 2.6792005810272013
# Validation Accuracy: 0.15404040404040403
#
# Epoch 7:
# Train Average Loss: 2.5114330391591206
# Train Accuracy: 0.20938628158844766
# Validation Average Loss: 2.67508256074154
# Validation Accuracy: 0.15824915824915825
#
# Epoch 8:
# Train Average Loss: 2.4788860245301834
# Train Accuracy: 0.21696750902527076
# Validation Average Loss: 2.672538388056386
# Validation Accuracy: 0.16077441077441076
#
# Epoch 9:
# Train Average Loss: 2.4447014762176074
# Train Accuracy: 0.22779783393501804
# Validation Average Loss: 2.6702122921092744
# Validation Accuracy: 0.16582491582491582
#
# Epoch 10:
# Train Average Loss: 2.409219053075632
# Train Accuracy: 0.24332129963898916
# Validation Average Loss: 2.6704743606875643
# Validation Accuracy: 0.16161616161616163
#
# Epoch 11:
# Train Average Loss: 2.3725468800816727
# Train Accuracy: 0.25740072202166064
# Validation Average Loss: 2.672876381312155
# Validation Accuracy: 0.16414141414141414
#
# Epoch 12:
# Train Average Loss: 2.330805934981749
# Train Accuracy: 0.2732851985559567
# Validation Average Loss: 2.674146806350862
# Validation Accuracy: 0.16835016835016836
#
# Epoch 13:
# Train Average Loss: 2.2872414344484624
# Train Accuracy: 0.2888086642599278
# Validation Average Loss: 2.6806063796534683
# Validation Accuracy: 0.16498316498316498
#
# Epoch 14:
# Train Average Loss: 2.2418672102022685
# Train Accuracy: 0.3003610108303249
# Validation Average Loss: 2.6881113758793584
# Validation Accuracy: 0.16666666666666666
#
# Epoch 15:
# Train Average Loss: 2.1903112758367933
# Train Accuracy: 0.3137184115523466
# Validation Average Loss: 2.6986746755914655
# Validation Accuracy: 0.16498316498316498
#
# Epoch 16:
# Train Average Loss: 2.1349018576343135
# Train Accuracy: 0.3303249097472924
# Validation Average Loss: 2.7086749654827695
# Validation Accuracy: 0.16498316498316498
#
# Epoch 17:
# Train Average Loss: 2.0808960357727986
# Train Accuracy: 0.3516245487364621
# Validation Average Loss: 2.728087887619481
# Validation Accuracy: 0.16077441077441076
#
# Epoch 18:
# Train Average Loss: 2.017959023554833
# Train Accuracy: 0.37509025270758123
# Validation Average Loss: 2.742574712644121
# Validation Accuracy: 0.16161616161616163
#
# Epoch 19:
# Train Average Loss: 1.952416497619574
# Train Accuracy: 0.39638989169675093
# Validation Average Loss: 2.7599817101000133
# Validation Accuracy: 0.1675084175084175
#
# Epoch 20:
# Train Average Loss: 1.8868077028529309
# Train Accuracy: 0.42382671480144407
# Validation Average Loss: 2.7818738009391812
# Validation Accuracy: 0.1734006734006734
#
# Epoch 21:
# Train Average Loss: 1.8127193049833663
# Train Accuracy: 0.45126353790613716
# Validation Average Loss: 2.8020305360607827
# Validation Accuracy: 0.17676767676767677
#
# Epoch 22:
# Train Average Loss: 1.7376653709136192
# Train Accuracy: 0.4747292418772563
# Validation Average Loss: 2.8269889121906524
# Validation Accuracy: 0.1750841750841751
#
# Epoch 23:
# Train Average Loss: 1.6671366620149854
# Train Accuracy: 0.5057761732851985
# Validation Average Loss: 2.8539073820467347
# Validation Accuracy: 0.16666666666666666
#
# Epoch 24:
# Train Average Loss: 1.5935106882549794
# Train Accuracy: 0.5328519855595668
# Validation Average Loss: 2.88036534280488
# Validation Accuracy: 0.1590909090909091
#
# Epoch 25:
# Train Average Loss: 1.5157004429545213
# Train Accuracy: 0.5541516245487365
# Validation Average Loss: 2.9204100278090146
# Validation Accuracy: 0.15993265993265993
#
# Epoch 26:
# Train Average Loss: 1.453057187257691
# Train Accuracy: 0.5703971119133574
# Validation Average Loss: 2.971906125746191
# Validation Accuracy: 0.16414141414141414
#
# Epoch 27:
# Train Average Loss: 1.3905628354110442
# Train Accuracy: 0.5945848375451264
# Validation Average Loss: 3.028598074158434
# Validation Accuracy: 0.16161616161616163
#
# Epoch 28:
# Train Average Loss: 1.3196925137447537
# Train Accuracy: 0.6050541516245488
# Validation Average Loss: 3.089953959590257
# Validation Accuracy: 0.1574074074074074
#
# Epoch 29:
# Train Average Loss: 1.2427166933617437
# Train Accuracy: 0.6364620938628159
# Validation Average Loss: 3.1419110555038707
# Validation Accuracy: 0.1590909090909091
#
# Epoch 30:
# Train Average Loss: 1.1764952581281696
# Train Accuracy: 0.6501805054151625
# Validation Average Loss: 3.230145205552329
# Validation Accuracy: 0.15235690235690236
#
# Epoch 31:
# Train Average Loss: 1.119625442553083
# Train Accuracy: 0.6685920577617328
# Validation Average Loss: 3.3211956409492878
# Validation Accuracy: 0.1574074074074074
#
# Epoch 32:
# Train Average Loss: 1.0642388435047025
# Train Accuracy: 0.6895306859205776
# Validation Average Loss: 3.346467607350462
# Validation Accuracy: 0.16582491582491582
#
# Epoch 33:
# Train Average Loss: 1.0009874376148953
# Train Accuracy: 0.7075812274368231
# Validation Average Loss: 3.4533616364604294
# Validation Accuracy: 0.1632996632996633
#
# Epoch 34:
# Train Average Loss: 0.9264761436717175
# Train Accuracy: 0.7328519855595668
# Validation Average Loss: 3.554587948603261
# Validation Accuracy: 0.1574074074074074
#
# Epoch 35:
# Train Average Loss: 0.8975373531506811
# Train Accuracy: 0.7382671480144405
# Validation Average Loss: 3.694771559551509
# Validation Accuracy: 0.15404040404040403
#
# Epoch 36:
# Train Average Loss: 0.8586374664564855
# Train Accuracy: 0.7447653429602888
# Validation Average Loss: 3.802461767036104
# Validation Accuracy: 0.1574074074074074
#
# Epoch 37:
# Train Average Loss: 1.4429387937383962
# Train Accuracy: 0.6101083032490975
# Validation Average Loss: 4.333830981142191
# Validation Accuracy: 0.1414141414141414
#
# Epoch 38:
# Train Average Loss: 0.6889230445188735
# Train Accuracy: 0.8158844765342961
# Validation Average Loss: 3.84829966548316
# Validation Accuracy: 0.14983164983164984
#
# Epoch 39:
# Train Average Loss: 0.6996043391821617
# Train Accuracy: 0.8043321299638989
# Validation Average Loss: 4.010270558623754
# Validation Accuracy: 0.1531986531986532
#
# Epoch 40:
# Train Average Loss: 0.6215897570663411
# Train Accuracy: 0.8342960288808664
# Validation Average Loss: 4.077422267258769
# Validation Accuracy: 0.1531986531986532
#
# Epoch 41:
# Train Average Loss: 0.5640660348782041
# Train Accuracy: 0.859927797833935
# Validation Average Loss: 4.183599325944278
# Validation Accuracy: 0.15067340067340068
#
# Epoch 42:
# Train Average Loss: 0.5199677134463934
# Train Accuracy: 0.8758122743682311
# Validation Average Loss: 4.286093161162302
# Validation Accuracy: 0.15235690235690236
#
# Epoch 43:
# Train Average Loss: 0.47848444010806856
# Train Accuracy: 0.8870036101083032
# Validation Average Loss: 4.374459202442105
# Validation Accuracy: 0.15151515151515152
#
# Epoch 44:
# Train Average Loss: 0.4516813537704385
# Train Accuracy: 0.8945848375451263
# Validation Average Loss: 4.479051079412903
# Validation Accuracy: 0.14983164983164984
#
# Epoch 45:
# Train Average Loss: 0.4189369479241354
# Train Accuracy: 0.9043321299638989
# Validation Average Loss: 4.574498215107003
# Validation Accuracy: 0.15151515151515152
#
# Epoch 46:
# Train Average Loss: 0.40222638331165383
# Train Accuracy: 0.9086642599277979
# Validation Average Loss: 4.693913422851049
# Validation Accuracy: 0.15067340067340068
#
# Epoch 47:
# Train Average Loss: 0.37607172809352946
# Train Accuracy: 0.9148014440433213
# Validation Average Loss: 4.775757201994308
# Validation Accuracy: 0.15572390572390574
#
# Epoch 48:
# Train Average Loss: 0.3561307383143084
# Train Accuracy: 0.9187725631768953
# Validation Average Loss: 4.870569402521307
# Validation Accuracy: 0.1531986531986532
# Epoch 49:
# Train Average Loss: 0.33401653560060024
# Train Accuracy: 0.9249097472924188
# Validation Average Loss: 4.949509829383105
# Validation Accuracy: 0.15235690235690236
#
# Epoch 50:
# Train Average Loss: 0.31880739583005113
# Train Accuracy: 0.9281588447653429
# Validation Average Loss: 5.030273093920364
# Validation Accuracy: 0.15404040404040403
#
# Epoch 51:
# Train Average Loss: 0.3053812548787155
# Train Accuracy: 0.9317689530685921
# Validation Average Loss: 5.094234000954162
# Validation Accuracy: 0.1531986531986532
#
# Epoch 52:
# Train Average Loss: 0.29675639618174693
# Train Accuracy: 0.9324909747292419
# Validation Average Loss: 5.18027760605218
# Validation Accuracy: 0.15235690235690236
#
# Epoch 53:
# Train Average Loss: 0.2808978542954483
# Train Accuracy: 0.935740072202166
# Validation Average Loss: 5.225852442911578
# Validation Accuracy: 0.14983164983164984
#
# Epoch 54:
# Train Average Loss: 0.27057186785802945
# Train Accuracy: 0.9382671480144404
# Validation Average Loss: 5.295011931396895
# Validation Accuracy: 0.14814814814814814
#
# Epoch 55:
# Train Average Loss: 0.26325627868786616
# Train Accuracy: 0.9393501805054152
# Validation Average Loss: 5.365715889015583
# Validation Accuracy: 0.14983164983164984
#
# Epoch 56:
# Train Average Loss: 0.25526277981295054
# Train Accuracy: 0.9411552346570398
# Validation Average Loss: 5.436054733867196
# Validation Accuracy: 0.14983164983164984
#
# Epoch 57:
# Train Average Loss: 0.2549921232548001
# Train Accuracy: 0.9415162454873646
# Validation Average Loss: 5.54868287108964
# Validation Accuracy: 0.14898989898989898
#
# Epoch 58:
# Train Average Loss: 0.2463403096267893
# Train Accuracy: 0.9415162454873646
# Validation Average Loss: 5.607323744481661
# Validation Accuracy: 0.14814814814814814
#
# Epoch 59:
# Train Average Loss: 0.2355969558661595
# Train Accuracy: 0.944043321299639
# Validation Average Loss: 5.624579707380096
# Validation Accuracy: 0.1473063973063973
#
# Epoch 60:
# Train Average Loss: 0.23718731646503352
# Train Accuracy: 0.9429602888086642
# Validation Average Loss: 5.741612322001345
# Validation Accuracy: 0.14562289562289563
#
# Epoch 61:
# Train Average Loss: 0.23343109335709997
# Train Accuracy: 0.9425992779783393
# Validation Average Loss: 5.802009823346379
# Validation Accuracy: 0.14646464646464646
#
# Epoch 62:
# Train Average Loss: 0.22746368280817025
# Train Accuracy: 0.944043321299639
# Validation Average Loss: 5.867512876337225
# Validation Accuracy: 0.1447811447811448
#
# Epoch 63:
# Train Average Loss: 0.2213054338194403
# Train Accuracy: 0.9451263537906137
# Validation Average Loss: 5.915988679686781
# Validation Accuracy: 0.14562289562289563
#
# Epoch 64:
# Train Average Loss: 0.22412908009458535
# Train Accuracy: 0.9451263537906137
# Validation Average Loss: 5.985802181642064
# Validation Accuracy: 0.14898989898989898
#
# Epoch 65:
# Train Average Loss: 0.21121631943577032
# Train Accuracy: 0.9472924187725632
# Validation Average Loss: 6.013161961077039
# Validation Accuracy: 0.14983164983164984
#
# Epoch 66:
# Train Average Loss: 0.2066504254668198
# Train Accuracy: 0.9476534296028881
# Validation Average Loss: 6.065791268139977
# Validation Accuracy: 0.15235690235690236
#
# Epoch 67:
# Train Average Loss: 0.20613184186095365
# Train Accuracy: 0.9476534296028881
# Validation Average Loss: 6.137404528531161
# Validation Accuracy: 0.14814814814814814
#
# Epoch 68:
# Train Average Loss: 0.2010929539530716
# Train Accuracy: 0.9490974729241878
# Validation Average Loss: 6.22041674013491
# Validation Accuracy: 0.14898989898989898
#
# Epoch 69:
# Train Average Loss: 0.19791830412317268
# Train Accuracy: 0.948014440433213
# Validation Average Loss: 6.232125556830204
# Validation Accuracy: 0.14814814814814814
#
# Epoch 70:
# Train Average Loss: 0.2168604299910232
# Train Accuracy: 0.948014440433213
# Validation Average Loss: 6.241388314500802
# Validation Accuracy: 0.15151515151515152
#
# Epoch 71:
# Train Average Loss: 0.19694888074260325
# Train Accuracy: 0.948375451263538
# Validation Average Loss: 6.329962605177754
# Validation Accuracy: 0.1531986531986532
#
# Epoch 72:
# Train Average Loss: 0.18992329424899407
# Train Accuracy: 0.9487364620938629
# Validation Average Loss: 6.369408096929993
# Validation Accuracy: 0.14814814814814814
#
# Epoch 73:
# Train Average Loss: 0.18819122664119362
# Train Accuracy: 0.9490974729241878
# Validation Average Loss: 6.413954660948679
# Validation Accuracy: 0.14983164983164984
#
# Epoch 74:
# Train Average Loss: 0.18562082863456505
# Train Accuracy: 0.9494584837545126
# Validation Average Loss: 6.455465361726806
# Validation Accuracy: 0.14898989898989898
#
# Epoch 75:
# Train Average Loss: 0.18233153218611914
# Train Accuracy: 0.9494584837545126
# Validation Average Loss: 6.493378427293566
# Validation Accuracy: 0.1473063973063973
#
# Epoch 76:
# Train Average Loss: 0.1802219891483603
# Train Accuracy: 0.9505415162454873
# Validation Average Loss: 6.549647106466068
# Validation Accuracy: 0.14562289562289563
#
# Epoch 77:
# Train Average Loss: 0.17744415483104622
# Train Accuracy: 0.9509025270758122
# Validation Average Loss: 6.577449405233467
# Validation Accuracy: 0.15235690235690236
#
# Epoch 78:
# Train Average Loss: 0.17608060466683728
# Train Accuracy: 0.9509025270758122
# Validation Average Loss: 6.617069424202145
# Validation Accuracy: 0.15067340067340068
#
# Epoch 79:
# Train Average Loss: 0.17514894808027287
# Train Accuracy: 0.9505415162454873
# Validation Average Loss: 6.659172632878878
# Validation Accuracy: 0.15235690235690236
#
# Epoch 80:
# Train Average Loss: 0.17557110740174456
# Train Accuracy: 0.9509025270758122
# Validation Average Loss: 6.713739433673897
# Validation Accuracy: 0.15151515151515152
#
# Epoch 81:
# Train Average Loss: 0.17349748919156485
# Train Accuracy: 0.9505415162454873
# Validation Average Loss: 6.736702035974573
# Validation Accuracy: 0.14814814814814814
#
# Epoch 82:
# Train Average Loss: 0.172774442019015
# Train Accuracy: 0.9509025270758122
# Validation Average Loss: 6.768970346611357
# Validation Accuracy: 0.14898989898989898
#
# Epoch 83:
# Train Average Loss: 0.17233316737499477
# Train Accuracy: 0.9509025270758122
# Validation Average Loss: 6.8081750420207525
# Validation Accuracy: 0.14814814814814814
#
# Epoch 84:
# Train Average Loss: 0.1711701524494357
# Train Accuracy: 0.9505415162454873
# Validation Average Loss: 6.836968680423518
# Validation Accuracy: 0.14983164983164984
#
# Epoch 85:
# Train Average Loss: 0.17020639514664881
# Train Accuracy: 0.9509025270758122
# Validation Average Loss: 6.871735873045744
# Validation Accuracy: 0.14898989898989898
#
# Epoch 86:
# Train Average Loss: 0.17031017022227551
# Train Accuracy: 0.9516245487364621
# Validation Average Loss: 6.911717071276321
# Validation Accuracy: 0.14898989898989898
#
# Epoch 87:
# Train Average Loss: 0.17068338983218162
# Train Accuracy: 0.951985559566787
# Validation Average Loss: 6.9495853751596774
# Validation Accuracy: 0.15151515151515152
#
# Epoch 88:
# Train Average Loss: 0.1707827152220351
# Train Accuracy: 0.9516245487364621
# Validation Average Loss: 6.918586156183622
# Validation Accuracy: 0.15488215488215487
#
# Epoch 89:
# Train Average Loss: 0.1673621251587403
# Train Accuracy: 0.951985559566787
# Validation Average Loss: 6.99319256034363
# Validation Accuracy: 0.14898989898989898
#
# Epoch 90:
# Train Average Loss: 0.16658962974156713
# Train Accuracy: 0.9516245487364621
# Validation Average Loss: 7.020992645109542
# Validation Accuracy: 0.14983164983164984
#
# Epoch 91:
# Train Average Loss: 0.16597616707482493
# Train Accuracy: 0.9516245487364621
# Validation Average Loss: 7.052222319323607
# Validation Accuracy: 0.15067340067340068
#
# Epoch 92:
# Train Average Loss: 0.16884104794005625
# Train Accuracy: 0.9523465703971119
# Validation Average Loss: 7.104548479972865
# Validation Accuracy: 0.15067340067340068
#
# Epoch 93:
# Train Average Loss: 0.16493688031546905
# Train Accuracy: 0.9516245487364621
# Validation Average Loss: 7.100031852722168
# Validation Accuracy: 0.15235690235690236
#
# Epoch 94:
# Train Average Loss: 0.16425871708117668
# Train Accuracy: 0.9516245487364621
# Validation Average Loss: 7.130104604393545
# Validation Accuracy: 0.15151515151515152
#
# Epoch 95:
# Train Average Loss: 0.1642257267387335
# Train Accuracy: 0.951985559566787
# Validation Average Loss: 7.171906702446215
# Validation Accuracy: 0.15151515151515152
#
# Epoch 96:
# Train Average Loss: 0.163306506521435
# Train Accuracy: 0.9516245487364621
# Validation Average Loss: 7.1821762463861845
# Validation Accuracy: 0.15067340067340068
#
# Epoch 97:
# Train Average Loss: 0.16360076636291151
# Train Accuracy: 0.951985559566787
# Validation Average Loss: 7.207713836772674
# Validation Accuracy: 0.15067340067340068
# Epoch 98:
# Train Average Loss: 0.16246824109597327
# Train Accuracy: 0.9516245487364621
# Validation Average Loss: 7.227896635781233
# Validation Accuracy: 0.14814814814814814
#
# Epoch 99:
# Train Average Loss: 0.16345745825380195
# Train Accuracy: 0.951985559566787
# Validation Average Loss: 7.284609200577142
# Validation Accuracy: 0.14898989898989898

# %%
pred_vs_acc = test_model(net, test_dataloader)[1]
# Out:
# Test Average Loss: 10.860161565985733
# Test Accuracy: 0.06733167082294264

# %%
check_preds(pred_vs_acc)[check_preds(pred_vs_acc)['is_correct']==1].sort_values(by='total', ascending=False)
# Out:
#      predicted  actual  total  is_correct  predicted_country  actual_country
# 75          12      12     14           1                 12              12
# 0            0       0      7           1                  0               0
# 37           6       6      6           1                  6               6
# 23           3       3      2           1                  3               3
# 30           4       4      2           1                  4               4
# 106         19      19      2           1                 19              19
# 48           7       7      1           1                  7               7

# %%
check_preds(pred_vs_acc)[check_preds(pred_vs_acc)['is_correct']==0].sort_values(by='total', ascending=False)
# Out:
#      predicted  actual  total  is_correct  predicted_country  actual_country
# 82          12      19     54           0                 12              19
# 70          12       7     54           0                 12               7
# 72          12       9     48           0                 12               9
# 64          12       1     47           0                 12               1
# 81          12      18     35           0                 12              18
# ..         ...     ...    ...         ...                ...             ...
# 54           7      16      1           0                  7              16
# 56           8       5      1           0                  8               5
# 58           8      11      1           0                  8              11
# 60           9      14      1           0                  9              14
# 105         19      10      1           0                 19              10
#
# [100 rows x 6 columns]

# %%
# For balanced experiment

# Create dataloader objects, move to GPU

# Train
x_train_balanced_tensor = torch.tensor(x_train_balanced, dtype=torch.float)
x_train_balanced_tensor = x_train_balanced_tensor.unsqueeze(dim=1)
y_train_balanced_tensor = torch.tensor(y_train_balanced, dtype=torch.long)

x_train_balanced_tensor = x_train_balanced_tensor.cuda()
y_train_balanced_tensor = y_train_balanced_tensor.cuda()

train_balanced_dataset = TensorDataset(x_train_balanced_tensor, y_train_balanced_tensor)
train_balanced_dataloader = DataLoader(train_balanced_dataset, batch_size=batch)

# Validation
x_valid_balanced_tensor = torch.tensor(x_valid_balanced, dtype=torch.float)
x_valid_balanced_tensor = x_valid_balanced_tensor.unsqueeze(dim=1)
y_valid_balanced_tensor = torch.tensor(y_valid_balanced, dtype=torch.long)

x_valid_balanced_tensor = x_valid_balanced_tensor.cuda()
y_valid_balanced_tensor = y_valid_balanced_tensor.cuda()

valid_balanced_dataset = TensorDataset(x_valid_balanced_tensor, y_valid_balanced_tensor)
valid_balanced_dataloader = DataLoader(valid_balanced_dataset, batch_size=batch)

# Test
x_test_balanced_tensor = torch.tensor(x_test_balanced, dtype=torch.float)
x_test_balanced_tensor = x_test_balanced_tensor.unsqueeze(dim=1)
y_test_balanced_tensor = torch.tensor(y_test_balanced, dtype=torch.long)

x_test_balanced_tensor = x_test_balanced_tensor.cuda()
y_test_balanced_tensor = y_test_balanced_tensor.cuda()

test_balanced_dataset = TensorDataset(x_test_balanced_tensor, y_test_balanced_tensor)
test_balanced_dataloader = DataLoader(test_balanced_dataset, batch_size=1)

# %%
# Initializing model, parameters, move to GPU

net = BalancedNet()
net = net.cuda()

batch = 32
optimizer = optim.SGD(net.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# Train Model
epochs = 50
train_accs, valid_accs = train_model(epochs, net, train_balanced_dataloader, valid_balanced_dataloader, optimizer, criterion)

epoch_list = [i for i in range(1, epochs+1)]
plt.figure()
plt.plot(epoch_list, train_accs, label='Train Accuracy')
plt.plot(epoch_list, valid_accs, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 0:
# Train Average Loss: 2.1631073935781076
# Train Accuracy: 0.2029608404966571
# Validation Average Loss: 2.1694171825175212
# Validation Accuracy: 0.18271334792122537
#
# Epoch 1:
# Train Average Loss: 2.124886509112893
# Train Accuracy: 0.23591212989493793
# Validation Average Loss: 2.144093584440469
# Validation Accuracy: 0.18708971553610504
#
# Epoch 2:
# Train Average Loss: 2.075255393298786
# Train Accuracy: 0.2507163323782235
# Validation Average Loss: 2.126058487193068
# Validation Accuracy: 0.19803063457330417
#
# Epoch 3:
# Train Average Loss: 2.037240463204917
# Train Accuracy: 0.2511938872970392
# Validation Average Loss: 2.1122229876612155
# Validation Accuracy: 0.22210065645514224
#
# Epoch 4:
# Train Average Loss: 2.0034671407032834
# Train Accuracy: 0.25644699140401145
# Validation Average Loss: 2.1254407342205424
# Validation Accuracy: 0.20350109409190373
#
# Epoch 5:
# Train Average Loss: 1.9647989219558046
# Train Accuracy: 0.281279847182426
# Validation Average Loss: 2.1119101037081798
# Validation Accuracy: 0.22319474835886213
#
# Epoch 6:
# Train Average Loss: 1.9425357494791462
# Train Accuracy: 0.2793696275071633
# Validation Average Loss: 2.132757379398304
# Validation Accuracy: 0.20678336980306344
#
# Epoch 7:
# Train Average Loss: 1.8977096751403444
# Train Accuracy: 0.30802292263610315
# Validation Average Loss: 2.157058969890002
# Validation Accuracy: 0.19037199124726478
#
# Epoch 8:
# Train Average Loss: 1.8306932466419514
# Train Accuracy: 0.33810888252148996
# Validation Average Loss: 2.140195923769761
# Validation Accuracy: 0.2100656455142232
#
# Epoch 9:
# Train Average Loss: 1.789154311078098
# Train Accuracy: 0.36341929321872013
# Validation Average Loss: 2.1745446443036034
# Validation Accuracy: 0.20350109409190373
#
# Epoch 10:
# Train Average Loss: 1.795800899252395
# Train Accuracy: 0.34765998089780326
# Validation Average Loss: 2.2276614228797427
# Validation Accuracy: 0.19474835886214442
#
# Epoch 11:
# Train Average Loss: 1.7622578500448918
# Train Accuracy: 0.3681948424068768
# Validation Average Loss: 2.2795275379322812
# Validation Accuracy: 0.19037199124726478
#
# Epoch 12:
# Train Average Loss: 1.6320981424312537
# Train Accuracy: 0.4379178605539637
# Validation Average Loss: 2.212228447394507
# Validation Accuracy: 0.19912472647702406
#
# Epoch 13:
# Train Average Loss: 1.5900544512807013
# Train Accuracy: 0.4498567335243553
# Validation Average Loss: 2.2076495173723485
# Validation Accuracy: 0.19803063457330417
#
# Epoch 14:
# Train Average Loss: 1.5358612030716088
# Train Accuracy: 0.4684813753581662
# Validation Average Loss: 2.243174436577561
# Validation Accuracy: 0.19693654266958424
#
# Epoch 15:
# Train Average Loss: 1.4933764054987013
# Train Accuracy: 0.49570200573065903
# Validation Average Loss: 2.2849167838399205
# Validation Accuracy: 0.1936542669584245
#
# Epoch 16:
# Train Average Loss: 1.4387624696992984
# Train Accuracy: 0.5157593123209169
# Validation Average Loss: 2.283797368439856
# Validation Accuracy: 0.18708971553610504
#
# Epoch 17:
# Train Average Loss: 1.3691699988748647
# Train Accuracy: 0.5367717287488061
# Validation Average Loss: 2.3012810462934965
# Validation Accuracy: 0.20021881838074398
#
# Epoch 18:
# Train Average Loss: 1.3220758091982137
# Train Accuracy: 0.5501432664756447
# Validation Average Loss: 2.378119553726664
# Validation Accuracy: 0.1838074398249453
#
# Epoch 19:
# Train Average Loss: 1.291305723538713
# Train Accuracy: 0.5448901623686724
# Validation Average Loss: 2.4410023767525573
# Validation Accuracy: 0.19146608315098468
#
# Epoch 20:
# Train Average Loss: 1.2125938987891334
# Train Accuracy: 0.6031518624641834
# Validation Average Loss: 2.4537466375780834
# Validation Accuracy: 0.19146608315098468
#
# Epoch 21:
# Train Average Loss: 1.1488372119643513
# Train Accuracy: 0.6241642788920726
# Validation Average Loss: 2.5178432662847006
# Validation Accuracy: 0.17943107221006566
#
# Epoch 22:
# Train Average Loss: 1.1044811523290852
# Train Accuracy: 0.6389684813753582
# Validation Average Loss: 2.5336339364166593
# Validation Accuracy: 0.17943107221006566
#
# Epoch 23:
# Train Average Loss: 1.0353306921585015
# Train Accuracy: 0.6628462273161414
# Validation Average Loss: 2.5965881822406596
# Validation Accuracy: 0.1761487964989059
#
# Epoch 24:
# Train Average Loss: 0.9683829942485095
# Train Accuracy: 0.6848137535816619
# Validation Average Loss: 2.64307621219226
# Validation Accuracy: 0.17833698030634573
#
# Epoch 25:
# Train Average Loss: 0.8996568941569032
# Train Accuracy: 0.707258834765998
# Validation Average Loss: 2.739362739629766
# Validation Accuracy: 0.18818380743982493
#
# Epoch 26:
# Train Average Loss: 0.8762629123790672
# Train Accuracy: 0.7211079274116523
# Validation Average Loss: 2.776110847356283
# Validation Accuracy: 0.18271334792122537
#
# Epoch 27:
# Train Average Loss: 0.8000332388631936
# Train Accuracy: 0.7559694364851958
# Validation Average Loss: 2.839501410135816
# Validation Accuracy: 0.1761487964989059
#
# Epoch 28:
# Train Average Loss: 0.7519835748611002
# Train Accuracy: 0.7621776504297995
# Validation Average Loss: 2.9508644934556156
# Validation Accuracy: 0.18271334792122537
#
# Epoch 29:
# Train Average Loss: 0.7029934687025795
# Train Accuracy: 0.7827125119388729
# Validation Average Loss: 2.9818706157692674
# Validation Accuracy: 0.18927789934354486
#
# Epoch 30:
# Train Average Loss: 0.654883750416374
# Train Accuracy: 0.7932187201528176
# Validation Average Loss: 3.1132773935664404
# Validation Accuracy: 0.19037199124726478
#
# Epoch 31:
# Train Average Loss: 0.5912721672850557
# Train Accuracy: 0.8271251193887297
# Validation Average Loss: 3.1538710484619474
# Validation Accuracy: 0.1838074398249453
#
# Epoch 32:
# Train Average Loss: 0.5668619190268894
# Train Accuracy: 0.8213944603629417
# Validation Average Loss: 3.3121313078398256
# Validation Accuracy: 0.19584245076586435
#
# Epoch 33:
# Train Average Loss: 0.5105181763156779
# Train Accuracy: 0.8414517669531996
# Validation Average Loss: 3.3314262657249
# Validation Accuracy: 0.19912472647702406
#
# Epoch 34:
# Train Average Loss: 0.4629022821058175
# Train Accuracy: 0.8595988538681948
# Validation Average Loss: 3.3738797644817593
# Validation Accuracy: 0.20350109409190373
#
# Epoch 35:
# Train Average Loss: 0.4344771650780807
# Train Accuracy: 0.879178605539637
# Validation Average Loss: 3.518035677903591
# Validation Accuracy: 0.2024070021881838
#
# Epoch 36:
# Train Average Loss: 0.39158188184472414
# Train Accuracy: 0.8954154727793696
# Validation Average Loss: 3.576083471269002
# Validation Accuracy: 0.19474835886214442
#
# Epoch 37:
# Train Average Loss: 0.3567236186482845
# Train Accuracy: 0.8997134670487106
# Validation Average Loss: 3.626085603784941
# Validation Accuracy: 0.20678336980306344
#
# Epoch 38:
# Train Average Loss: 0.35120285655004474
# Train Accuracy: 0.9011461318051576
# Validation Average Loss: 3.846676962120006
# Validation Accuracy: 0.19803063457330417
#
# Epoch 39:
# Train Average Loss: 0.3188231505361077
# Train Accuracy: 0.9135625596943648
# Validation Average Loss: 3.8710585642173982
# Validation Accuracy: 0.18818380743982493
#
# Epoch 40:
# Train Average Loss: 0.29781319303108944
# Train Accuracy: 0.9169054441260746
# Validation Average Loss: 3.9430618432209843
# Validation Accuracy: 0.1925601750547046
#
# Epoch 41:
# Train Average Loss: 0.29236902226093503
# Train Accuracy: 0.9159503342884432
# Validation Average Loss: 4.059277972715949
# Validation Accuracy: 0.1936542669584245
#
# Epoch 42:
# Train Average Loss: 0.26430670653737603
# Train Accuracy: 0.9235912129894938
# Validation Average Loss: 4.132652100118558
# Validation Accuracy: 0.2013129102844639
#
# Epoch 43:
# Train Average Loss: 0.24096772109034695
# Train Accuracy: 0.9336198662846227
# Validation Average Loss: 4.177804387633075
# Validation Accuracy: 0.19803063457330417
#
# Epoch 44:
# Train Average Loss: 0.22662851701685385
# Train Accuracy: 0.934574976122254
# Validation Average Loss: 4.216396730368716
# Validation Accuracy: 0.20021881838074398
#
# Epoch 45:
# Train Average Loss: 0.2242464683700883
# Train Accuracy: 0.9369627507163324
# Validation Average Loss: 4.371048389952344
# Validation Accuracy: 0.1936542669584245
#
# Epoch 46:
# Train Average Loss: 0.21111914536487864
# Train Accuracy: 0.938872970391595
# Validation Average Loss: 4.4109370838891495
# Validation Accuracy: 0.19803063457330417
#
# Epoch 47:
# Train Average Loss: 0.21045160523963577
# Train Accuracy: 0.9369627507163324
# Validation Average Loss: 4.52505967914406
# Validation Accuracy: 0.1936542669584245
#
# Epoch 48:
# Train Average Loss: 0.20306641189514907
# Train Accuracy: 0.938872970391595
# Validation Average Loss: 4.51033981415062
# Validation Accuracy: 0.20350109409190373
# Epoch 49:
# Train Average Loss: 0.19299364183898643
# Train Accuracy: 0.938872970391595
# Validation Average Loss: 4.68480858604548
# Validation Accuracy: 0.18271334792122537

# %%
pred_vs_acc = test_model(net, test_balanced_dataloader)[1]
# Out:
# Test Average Loss: 6.684716570442659
# Test Accuracy: 0.09216589861751152

# %%
check_preds(pred_vs_acc)[check_preds(pred_vs_acc)['is_correct']==1].sort_values(by='total', ascending=False)
# Out:
#     predicted  actual  total  is_correct  predicted_country  actual_country
# 18          2       2     13           1                  2               2
# 8           1       1      7           1                  1               1
# 46          5       5      6           1                  5               5
# 75          8       8      5           1                  8               8
# 0           0       0      4           1                  0               0
# 28          3       3      2           1                  3               3
# 65          7       7      2           1                  7               7
# 55          6       6      1           1                  6               6
